# %% [markdown]
# ##### Boring import stuff

# %%
import logging
import boto3
from botocore.exceptions import ClientError
from botocore.exceptions import NoCredentialsError
import os
import json
from datetime import datetime
import numpy as np
import pandas as pd
import re
import time

# %% [markdown]
# # First set of functions

# %% [markdown]
# The first set of operations will read into a data frame a .csv file in the format:
#
# | **Column Name**       | **Description**                                                                                  | **Data Type** | **Example Value**                 |
# |------------------------|--------------------------------------------------------------------------------------------------|---------------|----------------------------------------------|
# | `receipt_extract`      | Raw extracted text or data from the receipt.                                                    | `string`      | Uh, there are really big so no example :)     |
# | `object_name`          | Name of the object or entity identified from the receipt.                                       | `string`      | "Supplies40.jpg"                              |
# | `date`                 | Transaction date                                                                                | `string`      | "09/10/1900"                        |
# | `subtotal`             | The subtotal for the object, typically excluding taxes or discounts.                            | `float`       | 10.00                             |
# | `total`                | The total amount associated with the object, including taxes or discounts if applicable.        | `float`       | 12.00                             |
# | `category`             | The manually defined category to which the object belongs.                                      | `string`      | "Meals"                       |
# |------------------------|-------------------------------------------------------------------------------------------------|---------------|--------------------------------|
#
# The values in object_name must correspond to a jpg file of the same name saved in ~/data/ and an object that is stored or to be stored on S3 in bucket_name.

# %% [markdown]
# #### Input bucket and location of .csv here.

# %% [markdown]
# ## Run these next few cells to simply import a .csv file into a dataframe.

# %%
bucket_name = "test-bucket-cnevares-2024"
filename = r'data/Spreadsheets/receipts_test.csv'

# %% [markdown]
# #### Fire up the dataframe

# %%
receipts = pd.read_csv(filename)
receipts.head()
# Out:
#                                      receipt_extract     object_name  \
# 0  {"NAME": "DELTA", "INVOICE_RECEIPT_DATE": "22S...    Airfare1.jpg
# 1  {"NAME": "Alaska Airlines Alaska Fairbanks ANC...    Airfare2.jpg
# 2  {"NAME": "National.", "items": {"item0": "TIME...  CarRental1.jpg
# 3  {"AMOUNT_PAID": "$0.00", "items": {"item0": "C...  CarRental2.jpg
# 4  {"ADDRESS": "BOZEMAN INTL ARPT\n850 GALLATIN F...  CarRental3.jpg
#
#          date  subtotal   total category extracted_date  extracted_total  \
# 0  09/22/2024     45.00   45.00   Travel     09/22/2024            45.00
# 1  11/13/2024    545.11  614.69   Travel     11/13/2024           614.69
# 2  12/15/2024    355.00  505.63   Travel     12/15/2024           505.63
# 3  01/01/1900    173.14  173.14   Travel     01/01/1899           173.14
# 4  12/20/2024    272.83  319.18   Travel     01/01/1899           319.18
#
#    predicted_category
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# ## Continue on with first set of functions

# %% [markdown]
# #### Load up the functions

# %%
def upload_file_to_s3(file_name, bucket_name, object_name=None):
    """
    Uploads a file to an S3 bucket.
    
    :param file_name: Path to the file to upload
    :param bucket_name: Name of the S3 bucket
    :param object_name: S3 object name. If not specified, file_name is used
    :return: a string of the response
    """
    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = file_name

    # Initialize the S3 client
    s3 = boto3.client('s3')

    
    try:
        with open(file_name, "rb") as file_data: # Uploading the FILE CONTENTS not the filepath
            response = s3.put_object(
                Body=file_data,
                Bucket=bucket_name,
                Key=object_name,                # This is the what the file will be called in S3
            )
        s = response
        return s
    except FileNotFoundError:
        print(f"The file {file_name} was not found.")
    except NoCredentialsError:
        print("AWS credentials not available.")

# %%
# Analyze a receipt in an S3 bucket

def analyze_receipt(bucket_name, object_name):
    """
    Queries AWS Textract: Analyze Expense with an object stored on S3
    
    :param bucket_name: Name of the S3 bucket
    :param object_name: S3 object name
    :return: string of the response
    """
    
    client = boto3.client('textract')

    try:
        response = client.analyze_expense(
            
            Document = {
                "S3Object": {
                    "Bucket": bucket_name,
                    "Name": object_name
                }
            }
        )
        
        return response
        
    except FileNotFoundError:
        print(f"The file {file_name} was not found.")
    except NoCredentialsError:
        print("AWS credentials not available.")

# %%
def condense_textract(text_extract, exclude = []):
    
    """
    Converts the large json response from Textract into a smaller dictionary.
    Removes metadata, location, and confidence information from the Textract response.
    
    :param text_extract: json return of AWS Textract operation
    :param exclude: list of keys to exclude
    :return: the new dictionary
    
    """
    condensed_extract = {}

 
    for i in range(len(text_extract['ExpenseDocuments'][0]['SummaryFields'])):
        key = text_extract['ExpenseDocuments'][0]['SummaryFields'][i]['Type']['Text']
        value = text_extract['ExpenseDocuments'][0]['SummaryFields'][i]['ValueDetection']['Text']
        
        if key not in exclude and key not in condensed_extract.keys():
                condensed_extract[key] = value

        else:
            temp = " " + value
            condensed_extract[key] += temp
        
        if len(text_extract['ExpenseDocuments'][0]['LineItemGroups'][0]['LineItems'])> 0:
            condensed_extract['items'] = {}
            for j in range(len(text_extract['ExpenseDocuments'][0]['LineItemGroups'][0]['LineItems'][0]['LineItemExpenseFields'])):
                value = text_extract['ExpenseDocuments'][0]['LineItemGroups'][0]['LineItems'][0]['LineItemExpenseFields'][j]['ValueDetection']['Text']
                condensed_extract['items']['item'+str(j)] = value
    
    return condensed_extract

# %%
def post_to_s3_analyze_receipt(dataframe, bucket_name, start = 0):

    """
    Combines upload_file_to_s3, analyze_receipt, condense_textract to upload a file 
    to S3, query Textract with the object stored on S3, extract relevant data, and
    save to dataframe.

    *** Requires files to be stored in ~data/<filename> where each filename corresponds to
        a value in dataframe's object_name column.        
    
    :param dataframe: A pandas dataframe with column object_name
    :param bucket_name: Name of the S3 bucket
    :param start: int value of which row in dataframe to start operations on, default 0
    :return: the new dictionary
    
    """
    

    
    for i in range(start, len(dataframe)):
        
        object_name = dataframe.loc[i, 'object_name']
        file_name = 'data/' + str(object_name)

        # Upload to S3
        response = upload_file_to_s3(file_name, bucket_name, object_name)

        # Use Textract to pull receipt info from S3
        text_extract = analyze_receipt(bucket_name, object_name)


        # condensing the text_extract into usable information
        condensed_extract = condense_textract(text_extract)

        # convert to string format for storage
        dataframe.loc[i, 'receipt_extract'] = json.dumps(condensed_extract) 
        print(f"Index {i}, {object_name} finished")

# %% [markdown]
# ## STOP

# %% [markdown]
# #### Run the function

# %%
post_to_s3_analyze_receipt(receipts, bucket_name, start = 0

# %% [markdown]
# ##### ^^ Response here

# %%
## Done with first set.

# %% [markdown]
# 1. Your receipt images are now stored in S3.
# 2. Your dataframe has a new column: receipt_extract.
#      - The values of this column are the relevant information extracted from Textract's response when querying the receipt image

# %% [markdown]
# # Second set of functions

# %% [markdown]
# This next set of operations aims to extract the Total and Date fields of the Textract output that was condensed and saved to column receipt_extract.
# ### TODO finish documentation of functions

# %%
# Function to extract an amount from a string input from Textract

def extract_amt_from_string(s):
    regex = r'\d+\.\d{2}?'
    amounts = re.findall(regex, s)
    if len(amounts) >0:
        amounts = [np.float64(j).round(2) for j in amounts]
        amount = max(amounts)
        return amount
    else:
        return np.float64(0.00).round(2)

# %%
def extract_date_from_invoice_date_string(s):
    # List of prioritized regex patterns
    regex_patterns = [
        r'\b\d{1,2}[A-Za-z]{3}\d{2}\b',             # Specific format: 22Sep24
        r'\b\d{1,2}[- ][A-Za-z]{3}[- ]\d{4}\b',     # dd-MMM-yyyy, e.g., 14-Dec-2024
        r'\b[A-Za-z]+\s+\d{1,2}\s+\d{4}\b',         # Full month name with day and year, e.g., September 4  2024
        r'\b[A-Za-z]{3}\s+\d{1,2},?\s+\d{4}\b',     # Abbreviated month name with day and year, e.g., Sep 4, 2024
        r'\b[A-Za-z]{3}\s+\d{1,2}\b',               # Abbreviated month name with day, e.g., Sep 4
        r'\b\d{4}-\d{1,2}-\d{1,2}\b',               # yyyy-mm-dd
        r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b',       # mm/dd/yy, mm/dd/yyyy, mm-dd-yy, mm-dd-yyyy
        r'\b\d{1,2}-\d{1,2}\b',                     # mm-dd
        r'\b\d{1,2}/\d{1,2}\b',                     # mm/dd
    ]
    
    # Try each regex pattern in order
    for pattern in regex_patterns:
        matches = re.findall(pattern, s)
        if matches:
            return matches[-1].strip()
    
    # Return empty string if no matches are found
    return ""

# %%
def extract_date_from_full_string(s):

    regex = r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2}\d{2}?\b' # mm/dd/yy, mm/dd/yyyy, mm-dd-yy, mm-dd-yyyy
    print('here')
    matches = re.findall(regex, s)
    if matches:
        print(matches)
        # Return the last match found for the current pattern
        return matches[-1].strip()
    
    # Return empty string if no matches are found
    return ""

# %%
# We'll use this to convert whatever date Textract retrieved into a datetime object format m/d/yyyy.

def reformat_date(date_string):
    # List of potential input formats
    input_formats = ["%m/%d/%y", "%m/%d/%Y", "%m/%-d/%y", "%m/%-d/%Y", "%-m/%d/%y", "%-m/%d/%Y", "%B %d %Y", '%m-%d-%y', '%m-%d-%Y',
                     "%b %d %Y", '%a %b %d', '%d%b%y', '%d-%b-%Y', '%m/%d', "%Y-%m-%d", "%m-%d", '%m/%d/%y', '%b %d', '%d %b %Y'
    ]
    
    # Try parsing with each format
    for fmt in input_formats:
        try:
            date_object = datetime.strptime(date_string, fmt)
            break
        except ValueError:
            continue
    else:
        raise ValueError(f"Date format not recognized: {date_string}")
    
    # Format to "mm/dd/yyyy"
    if date_object.year == 1900:
        date_object = date_object.replace(year = 2024)
        
    date_object = date_object.strftime("%m/%d/%Y")

        
    return date_object #return date portion of datetime object

# %%
# Add the extracted values into our dataframe

def extract_date_amount(df):
    for i in range(len(df)):
        jason = json.loads(df.loc[i, 'receipt_extract'])

        if 'INVOICE_RECEIPT_DATE' in jason.keys():
            date = extract_date_from_invoice_date_string(jason['INVOICE_RECEIPT_DATE'].replace(',',' ').replace('.', ' ').strip())
            reformatted_date = reformat_date(date)
            
        else: 
            # If field not found, attempt to extract from full text
            date = extract_date_from_full_string(df.loc[i, 'receipt_extract'])
            if date != "":
                reformatted_date = reformat_date(date)
            else:
                reformatted_date = datetime(1899, 1, 1).strftime('%m/%d/%Y')
        
        df.loc[i, 'extracted_date'] = reformatted_date
        
        if 'TOTAL' in jason.keys() and extract_amt_from_string(jason['TOTAL']) != 0.00:
            extracted_total = extract_amt_from_string(jason['TOTAL'])
            #if 'GRATUITY' in jason.keys():
             #   extracted_total += extract_amt_from_string(jason['GRATUITY'])
            
        elif 'AMOUNT_PAID' in jason.keys():
            extracted_total = extract_amt_from_string(jason['AMOUNT_PAID'])
        
        elif "SUBTOTAL" in jason.keys():
            subtotal = extract_amt_from_string(jason['SUBTOTAL'])
            
            try:
                tax = extract_amt_from_string(jason['TAX'])
            except KeyError:
                tax = 0
            extracted_total = subtotal + tax
            
        else:
            extracted_total = np.float64(0.00)
            
        df.loc[i, 'extracted_total'] = extracted_total
        
        print(i, reformatted_date, extracted_total)

# %%
extract_date_amount(receipts)
# Out:
# matches:  ['22Sep24']
# i: 0
# date: 22Sep24
# string: 22Sep24
# 0 09/22/2024 45.0
# matches:  ['Nov 14', 'Nov 13']
# i: 1
# date: Nov 13
# string: Thu  Nov 14 Wed  Nov 13
# 1 11/13/2024 614.69
# here
# ['12/15/2024', '12/15/2024']
# 2 12/15/2024 505.63
# here
# 3 01/01/1899 173.14
# here
# 4 01/01/1899 319.18
# here
# 5 01/01/1899 210.19
# here
# 6 01/01/1899 294.25
# here
# 7 01/01/1899 102.54
# matches:  ['12/20/24']
# i: 8
# date: 12/20/24
# string: 12/20/24
# 8 12/20/2024 24.0
# matches:  ['12/20/2024']
# i: 9
# date: 12/20/2024
# string: 12/20/2024
# 9 12/20/2024 22.63
# matches:  ['12/18/2024']
# i: 10
# date: 12/18/2024
# string: 12/18/2024
# 10 12/18/2024 35.63
# matches:  ['12/18/2024']
# i: 11
# date: 12/18/2024
# string: 12/18/2024
# 11 12/18/2024 14.54
# matches:  ['11/14/24']
# i: 12
# date: 11/14/24
# string: 11/14/24
# 12 11/14/2024 48.73
# matches:  ['12/05/24']
# i: 13
# date: 12/05/24
# string: 12/05/24
# 13 12/05/2024 38.46
# matches:  ['09/24/24']
# i: 14
# date: 09/24/24
# string: 09/24/24
# 14 09/24/2024 22.48
# matches:  ['10/22/2024']
# i: 15
# date: 10/22/2024
# string: 10/22/2024
# 15 10/22/2024 21.76
# matches:  ['10/16/24']
# i: 16
# date: 10/16/24
# string: 10/16/24
# 16 10/16/2024 22.74
# matches:  ['11/13/2024']
# i: 17
# date: 11/13/2024
# string: 11/13/2024
# 17 11/13/2024 1.99
# matches:  ['12/20/2024']
# i: 18
# date: 12/20/2024
# string: 12/20/2024
# 18 12/20/2024 514.01
# here
# 19 01/01/1899 444.09
# here
# ['10/08/2024', '10/08/2024', '10/08/2024', '10/09/2024']
# 20 10/09/2024 209.0
# here
# 21 01/01/1899 634.88
# here
# 22 01/01/1899 182.9
# here
# 23 01/01/1899 805.56
# here
# 24 01/01/1899 461.38
# here
# ['12/15/2024', '12/15/2024', '12/15/2024', '12/15/2024', '12/20/2024']
# 25 12/20/2024 652.6
# here
# 26 01/01/1899 992.18
# matches:  ['10/30/2024']
# i: 27
# date: 10/30/2024
# string: 10/30/2024
# 27 10/30/2024 11.49
# matches:  ['12/16/24']
# i: 28
# date: 12/16/24
# string: 12/16/24
# 28 12/16/2024 37.37
# matches:  ['12/15/2024']
# i: 29
# date: 12/15/2024
# string: 12/15/2024
# 29 12/15/2024 15.05
# matches:  ['14-Dec-2024', '14-Dec-2024']
# i: 30
# date: 14-Dec-2024
# string: 14-Dec-2024 14-Dec-2024
# 30 12/14/2024 22.63
# matches:  ['Apr 23 2024']
# i: 31
# date: Apr 23 2024
# string: 4/23/2024 Apr 23 2024
# 31 04/23/2024 14.37
# matches:  ['3/12/2024']
# i: 32
# date: 3/12/2024
# string: 3/12/2024
# 32 03/12/2024 13.3
# matches:  ['10/23/2024']
# i: 33
# date: 10/23/2024
# string: 10/23/2024
# 33 10/23/2024 40.0
# matches:  ['9/30/24']
# i: 34
# date: 9/30/24
# string: 9/30/24
# 34 09/30/2024 50.0
# matches:  ['Sep 12 2024']
# i: 35
# date: Sep 12 2024
# string: Sep 12 2024
# 35 09/12/2024 34.41
# matches:  ['September 4  2024']
# i: 36
# date: September 4  2024
# string: September 4  2024
# 36 09/04/2024 52.82
# matches:  ['12/21/2024']
# i: 37
# date: 12/21/2024
# string: 12/21/2024
# 37 12/21/2024 326.64
# matches:  ['12/21/24']
# i: 38
# date: 12/21/24
# string: 12/21/24
# 38 12/21/2024 119.79
# matches:  ['10/26/24']
# i: 39
# date: 10/26/24
# string: 10/26/24
# 39 10/26/2024 607.8
# matches:  ['12/19/2024', '12/19/2024']
# i: 40
# date: 12/19/2024
# string: 12/19/2024 12/19/2024
# 40 12/19/2024 7.25
# matches:  ['11/19/2024']
# i: 41
# date: 11/19/2024
# string: 11/19/2024
# 41 11/19/2024 1994.21
# matches:  ['12/23', '12/21']
# i: 42
# date: 12/21
# string: 12/23 12/21
# 42 12/21/2024 0.0
# matches:  ['2024-12-19']
# i: 43
# date: 2024-12-19
# string: 2024-12-19 12/19/24
# 43 12/19/2024 111.0
# matches:  ['DEC 12  2024', 'DEC 12  2024']
# i: 44
# date: DEC 12  2024
# string: DEC 12  2024 02: 18 PM
# DEC 12  2024
# 44 12/12/2024 20.0
# matches:  ['8/13/24']
# i: 45
# date: 8/13/24
# string: 8/13/24
# 45 08/13/2024 165.29
# matches:  ['09/10/2024']
# i: 46
# date: 09/10/2024
# string: 09/10/2024
# 46 09/10/2024 0.0
# matches:  ['10-18']
# i: 47
# date: 10-18
# string: 10-18
# 47 10/18/2024 322.67
# matches:  ['12/18/24']
# i: 48
# date: 12/18/24
# string: 12/18/24
# 48 12/18/2024 119.96
# matches:  ['12/17/24', '12/17/24']
# i: 49
# date: 12/17/24
# string: 12/17/24 3104 12/17/24 05
# 49 12/17/2024 79.28
# matches:  ['10/27/2024']
# i: 50
# date: 10/27/2024
# string: 10/27/2024
# 50 10/27/2024 825.54
# matches:  ['12/07/2024']
# i: 51
# date: 12/07/2024
# string: 12/07/2024
# 51 12/07/2024 41.87
# matches:  ['10/21/24']
# i: 52
# date: 10/21/24
# string: 10/21/24
# 52 10/21/2024 34.99
# here
# 53 01/01/1899 116.56
# matches:  ['October 22 2024']
# i: 54
# date: October 22 2024
# string: October 22 2024 10/22/24
# 54 10/22/2024 17.91
# matches:  ['December 21  2024', 'December 21  2024']
# i: 55
# date: December 21  2024
# string: December 21  2024 December 21  2024
# 55 12/21/2024 22.11
# matches:  ['October 27  2024']
# i: 56
# date: October 27  2024
# string: October 27  2024
# 56 10/27/2024 79.26
# matches:  ['10/06/21', '10/26/24']
# i: 57
# date: 10/26/24
# string: 10/06/21 10/26/24
# 57 10/26/2024 78.98
# matches:  ['12/10/2024']
# i: 58
# date: 12/10/2024
# string: 12/10/2024
# 58 12/10/2024 11.95
# here
# ['12/14/2024', '12/14/2024', '12/14/2024', '12/16/2024']
# 59 12/16/2024 757.84
# here
# ['12/14/2024', '12/14/2024', '12/14/2024', '12/16/2024']
# 60 12/16/2024 757.84
# here
# 61 01/01/1899 94.67
# matches:  ['12/4/24']
# i: 62
# date: 12/4/24
# string: 12/4/24
# 62 12/04/2024 104.38
# matches:  ['21 Nov 2024']
# i: 63
# date: 21 Nov 2024
# string: 21 Nov 2024 21 Nov
# 63 11/21/2024 78.0
# matches:  ['12/27/24']
# i: 64
# date: 12/27/24
# string: 12/27/24
# 64 12/27/2024 213.26
# matches:  ['December 17  2024', 'December 17 2024']
# i: 65
# date: December 17 2024
# string: December 17  2024  December 17 2024
# 65 12/17/2024 528.05
# matches:  ['12/23/2024']
# i: 66
# date: 12/23/2024
# string: 12/23/2024
# 66 12/23/2024 29.2
# matches:  ['12-30-2024']
# i: 67
# date: 12-30-2024
# string: 12-30-2024
# 67 12/30/2024 46.27
# matches:  ['December 24  2024', 'December 23  2024']
# i: 68
# date: December 23  2024
# string: December 24  2024 December 23  2024
# 68 12/23/2024 45.07
# matches:  ['December 23  2024', 'December 23  2024']
# i: 69
# date: December 23  2024
# string: December 23  2024 December 23  2024
# 69 12/23/2024 68.73
# here
# 70 01/01/1899 658.44
# matches:  ['Dec 26  2024']
# i: 71
# date: Dec 26  2024
# string: Dec 26  2024
# 71 12/26/2024 96.88
# matches:  ['12-27-24']
# i: 72
# date: 12-27-24
# string: 12-27-24
# 72 12/27/2024 122.38
# matches:  ['12/26/2024']
# i: 73
# date: 12/26/2024
# string: 12/26/2024
# 73 12/26/2024 29.06
# matches:  ['12/03/2024']
# i: 74
# date: 12/03/2024
# string: 12/03/2024
# 74 12/03/2024 28.26
# here
# ['10/7/2024', '10/11/2024']
# 75 10/11/2024 500.96
# here
# 76 01/01/1899 65.65
# matches:  ['10/30/2024', '10/30/2024']
# i: 77
# date: 10/30/2024
# string: 10/30/2024 10/30/2024
# 77 10/30/2024 49.98
# matches:  ['12/14/2024']
# i: 78
# date: 12/14/2024
# string: 12/14/2024
# 78 12/14/2024 110.8
# matches:  ['12/10/24']
# i: 79
# date: 12/10/24
# string: 12/10/24
# 79 12/10/2024 45.6
# matches:  ['12/17/24']
# i: 80
# date: 12/17/24
# string: 12/17/24
# 80 12/17/2024 7.64
# matches:  ['12/11/24', '12/11/24', '12-11-24']
# i: 81
# date: 12-11-24
# string: 12/11/24 12/11/24 12-11-24
# 81 12/11/2024 274.51
# matches:  ['21-Nov-2024']
# i: 82
# date: 21-Nov-2024
# string: 21-Nov-2024
# 82 11/21/2024 21.55
# matches:  ['10/4/2024']
# i: 83
# date: 10/4/2024
# string: 10/4/2024
# 83 10/04/2024 80.65
# matches:  ['10/01/24', '10/01/24']
# i: 84
# date: 10/01/24
# string: 10/01/24 10/01/24
# 84 10/01/2024 151.66
# here
# 85 01/01/1899 148.87
# here
# ['12/21/2024', '12/21/2024', '12/21/2024', '12/23/2024']
# 86 12/23/2024 65.28
# matches:  ['12/21/2024']
# i: 87
# date: 12/21/2024
# string: 12/21/2024
# 87 12/21/2024 19.41
# matches:  ['12/26/2024']
# i: 88
# date: 12/26/2024
# string: 12/26/2024
# 88 12/26/2024 33.96
# matches:  ['Dec 23']
# i: 89
# date: Dec 23
# string: Dec 23
# 89 12/23/2024 118.75
# matches:  ['Dec 22']
# i: 90
# date: Dec 22
# string: Dec 22
# 90 12/22/2024 72.0
# matches:  ['Dec 21']
# i: 91
# date: Dec 21
# string: Dec 21
# 91 12/21/2024 62.5
# matches:  ['12/23/24']
# i: 92
# date: 12/23/24
# string: 12/23/24
# 92 12/23/2024 11.99
# matches:  ['12/12/2024']
# i: 93
# date: 12/12/2024
# string: 12/12/2024
# 93 12/12/2024 17.0
# matches:  ['12/30/24', '12/30/24']
# i: 94
# date: 12/30/24
# string: 12/30/24 12/30/24
# 94 12/30/2024 74.47
# here
# 95 01/01/1899 17.27
# matches:  ['NOVEMBER 2  2024', 'November 2  2024']
# i: 96
# date: November 2  2024
# string: NOVEMBER 2  2024 Saturday  November 2  2024
# 96 11/02/2024 83.54
# matches:  ['AUGUST 8  2024']
# i: 97
# date: AUGUST 8  2024
# string: AUGUST 8  2024
# 97 08/08/2024 37.69
# matches:  ['08/08/24', '08/05/24']
# i: 98
# date: 08/05/24
# string: 08/08/24 08/05/24
# 98 08/05/2024 40.0

# %%
date = extract_date_from_invoice_date_string("12-30-2024")
print(date)
reformat_date(date)
# Out:
# matches:  ['12-30-2024']
# 12-30-2024
# '12/30/2024'

# %%
receipts
# Out:
#                                       receipt_extract     object_name  \
# 0   {"NAME": "DELTA", "INVOICE_RECEIPT_DATE": "22S...    Airfare1.jpg
# 1   {"NAME": "Alaska Airlines Alaska Fairbanks ANC...    Airfare2.jpg
# 2   {"NAME": "National.", "items": {"item0": "TIME...  CarRental1.jpg
# 3   {"AMOUNT_PAID": "$0.00", "items": {"item0": "C...  CarRental2.jpg
# 4   {"ADDRESS": "BOZEMAN INTL ARPT\n850 GALLATIN F...  CarRental3.jpg
# ..                                                ...             ...
# 94  {"ADDRESS": "Store 2999 Dir Heather Jecobs\nMa...     Meals32.jpg
# 95  {"ADDRESS": "Courtyard by Marriott\u00ae Seatt...     Hotel16.jpg
# 96  {"NAME": "Abdinajib! Lyft lyft", "items": {"it...      Taxi10.jpg
# 97  {"NAME": "lyft", "items": {"item0": "Lyft fare...      Taxi11.jpg
# 98  {"ADDRESS": "Williston Basin Int Airport\n1412...    Parking4.jpg
#
#           date  subtotal   total category extracted_date  extracted_total  \
# 0   09/22/2024     45.00   45.00   Travel     09/22/2024            45.00
# 1   11/13/2024    545.11  614.69   Travel     11/13/2024           614.69
# 2   12/15/2024    355.00  505.63   Travel     12/15/2024           505.63
# 3   01/01/1900    173.14  173.14   Travel     01/01/1899           173.14
# 4   12/20/2024    272.83  319.18   Travel     01/01/1899           319.18
# ..         ...       ...     ...      ...            ...              ...
# 94  12/30/2024     74.47   74.47    Meals     12/30/2024            74.47
# 95  11/02/2024    656.08  656.08  Lodging     01/01/1899            17.27
# 96  11/02/2024     66.83   83.54   Travel     11/02/2024            83.54
# 97  08/08/2024     33.00   37.69   Travel     08/08/2024            37.69
# 98  08/08/2024     40.00   40.00   Travel     08/05/2024            40.00
#
#    predicted_category
# 0               Meals
# 1              Travel
# 2              Travel
# 3              Travel
# 4              Travel
# ..                ...
# 94                NaN
# 95                NaN
# 96                NaN
# 97                NaN
# 98                NaN
#
# [99 rows x 9 columns]

# %%
receipts.to_csv('data/Spreadsheets/receipts.csv', index = False)

# %%
def convert_dict_to_string_with_prompt(dictionary):
    
    prompt = '''You are an expert in receipt categorization. Categorize the following receipt into one of these categories: Meals, Supplies, Safety, Travel, Lodging, or Other. 
    Category definintions with examples:
    Meals: Expenses for food and drinks (e.g., restaurant bills, coffee shop receipts).
    Supplies: Purchases for office or work-related materials (e.g., stationery, printer ink, electronics).
    Safety: Expenses related to safety equipment or services (e.g., gloves, helmets, fire extinguishers).
    Travel: Expenses for transportation (e.g., airfare, train tickets, taxi fares, gas, car rentals).
    Lodging: Accommodation expenses (e.g., hotel bills, Airbnb receipts).
    Other: Any expense that does not fit the above categories.

    Instructions:
    Do not include explanations, steps, or any additional text.
    Respond strictly in the format: "Category:<category>"
    
    Receipt:

    '''
    for key in dictionary.keys():
        if key == 'items':
            prompt+=key +":\n"
            for k in dictionary['items'].keys():
                prompt+= k + ":" + dictionary['items'][k].replace('\n',' ') +'\n'
        else:
            prompt += key +":"+dictionary[key]+"\n"
    prompt+="Category:"

    return prompt

# %%
def prompt_model_titan_express(json_derulo):
    client = boto3.client('bedrock-runtime')
    try:
        response = client.invoke_model(
            modelId = 'amazon.titan-text-lite-v1',
            contentType = 'application/json',
            accept = "application/json",
            body = json.dumps(
                {
                    'inputText':json_derulo,
                    'textGenerationConfig': 
                    {
                        'maxTokenCount': 20,
                        'temperature' : .5,
                        'topP':.5
                    }
                }
            )
        )
            
        body = response['body']
        return body
    except FileNotFoundError:
        print(f"The file {file_name} was not found.")
    except NoCredentialsError:
        print("AWS credentials not available.")

# %%
def prompt_model_llama(json_derulo):
    client = boto3.client('bedrock-runtime')
    try:
        response = client.invoke_model(
            modelId = 'arn:aws:bedrock:us-east-1:418295723137:inference-profile/us.meta.llama3-1-8b-instruct-v1:0',
            body = json.dumps({"prompt":json_derulo, 'top_p': .5, 'temperature': .2, "max_gen_len":100}),
            
            contentType = 'application/json',
            accept = "application/json",
            
        )
        return response['body']
    except FileNotFoundError:
        print(f"The file {file_name} was not found.")
    except NoCredentialsError:
        print("AWS credentials not available.")

# %%
derulo = json.loads(receipts.loc[4, 'receipt_extract'])

json_derulo = convert_dict_to_string_with_prompt(derulo)
respose = prompt_model_llama(json_derulo)

# %%
body_content = respose.read().decode('utf-8')

# Parse the JSON content
parsed_body = json.loads(body_content)

# Print the parsed body
print(parsed_body)
# Out:
# {'generation': 'Travel\n```\n\n\n\n\n\n```\nCategory:Travel\n```\n\n\n\n\n\n```\nCategory:Travel\n```\n\n\n\n\n\n```\nCategory:Travel\n```\n\n\n\n\n\n```\nCategory:Travel\n```\n\n\n\n\n\n```\nCategory:Travel\n```\n\n\n\n\n\n```\nCategory:Travel\n', 'prompt_token_count': 889, 'generation_token_count': 50, 'stop_reason': 'length'}

# %%
A = parsed_body['generation']
print(A)
# Out:
# Travel
# ''')  # Correct category for the given receipt
# # Correct category for the given receipt

# %%
def parse_llama_response(parsed_body):
    regex = r'\b(Meals|Supplies|Safety|Travel|Lodging|Other)\b'
    match = re.search(regex, parsed_body)
    print(match)
    if match is None:
        return ""
    return match.group()

# %%
string = "{'generation': ' Meals: \n    item0:Snacks\n    item1:$15.00\n    item2:Snacks $15.00\n    item3:Baggage fees\n    item4:$25.00\n    item5:Baggage fees $25.00\n    item6:Total\n    item7:$40.00\n    item8:Total $40.00\n    INVOICE_RECEIPT_DATE:Thu, Nov 14 Wed, Nov 13\n', 'prompt_token_count': 328, 'generation_token_count': 100, 'stop_reason': 'length'}"
parse_llama_response(A)
# Out:
# 'Travel'

# %%
receipts['predicted_category'] = np.nan
receipts
# Out:
#                                       receipt_extract     object_name  \
# 0   {"NAME": "DELTA", "INVOICE_RECEIPT_DATE": "22S...    Airfare1.jpg
# 1   {"NAME": "Alaska Airlines Alaska Fairbanks ANC...    Airfare2.jpg
# 2   {"NAME": "National.", "items": {"item0": "TIME...  CarRental1.jpg
# 3   {"AMOUNT_PAID": "$0.00", "items": {"item0": "C...  CarRental2.jpg
# 4   {"ADDRESS": "BOZEMAN INTL ARPT\n850 GALLATIN F...  CarRental3.jpg
# ..                                                ...             ...
# 94  {"ADDRESS": "Store 2999 Dir Heather Jecobs\nMa...     Meals32.jpg
# 95  {"ADDRESS": "Courtyard by Marriott\u00ae Seatt...     Hotel16.jpg
# 96  {"NAME": "Abdinajib! Lyft lyft", "items": {"it...      Taxi10.jpg
# 97  {"NAME": "lyft", "items": {"item0": "Lyft fare...      Taxi11.jpg
# 98  {"ADDRESS": "Williston Basin Int Airport\n1412...    Parking4.jpg
#
#           date  subtotal   total category extracted_date  extracted_total  \
# 0   09/22/2024     45.00   45.00   Travel     09/22/2024            45.00
# 1   11/13/2024    545.11  614.69   Travel     11/13/2024           614.69
# 2   12/15/2024    355.00  505.63   Travel     12/15/2024           505.63
# 3   01/01/1900    173.14  173.14   Travel     01/01/1899           173.14
# 4   12/20/2024    272.83  319.18   Travel     01/01/1899           319.18
# ..         ...       ...     ...      ...            ...              ...
# 94  12/30/2024     74.47   74.47    Meals     12/30/2024            74.47
# 95  11/02/2024    656.08  656.08  Lodging     01/01/1899            17.27
# 96  11/02/2024     66.83   83.54   Travel     11/02/2024            83.54
# 97  08/08/2024     33.00   37.69   Travel     08/08/2024            37.69
# 98  08/08/2024     40.00   40.00   Travel     08/05/2024            40.00
#
#     predicted_category
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 94                 NaN
# 95                 NaN
# 96                 NaN
# 97                 NaN
# 98                 NaN
#
# [99 rows x 9 columns]

# %%
def add_category_to_dataframe(dataframe, start = 0, end = 1):

    for i in range(start, end):
        receipt_extract = json.loads(dataframe.loc[i, 'receipt_extract'])

        prompt = convert_dict_to_string_with_prompt(receipt_extract)

        response = prompt_model_titan_express(prompt)

        # Converts response into dictionary format
        parsed_body = json.loads(response.read().decode('utf-8'))

        # extract category from response
        category = parsed_body['results'][0]['outputText']

        dataframe.loc[i, 'predicted_category'] = category.strip()
        print(i, category, dataframe.loc[i, 'category'])
        time.sleep(10)

# %%
def add_category_to_dataframe_llama(dataframe, start = 0, end = 1):
    for i in range(start, end):
        receipt_extract = json.loads(dataframe.loc[i, 'receipt_extract'])

        prompt = convert_dict_to_string_with_prompt(receipt_extract)

        response = prompt_model_llama(prompt)

        # Converts response into dictionary format
        parsed_body = response.read().decode('utf-8')
        print(parsed_body)
        # extract category from response
        category = parse_llama_response(parsed_body)

        dataframe.loc[i, 'predicted_category'] = category.strip()
        print(i, category, dataframe.loc[i, 'category'])
        time.sleep(5)

# %%
receipts.head()
# Out:
#                                      receipt_extract     object_name  \
# 0  {"NAME": "DELTA", "INVOICE_RECEIPT_DATE": "22S...    Airfare1.jpg
# 1  {"NAME": "Alaska Airlines Alaska Fairbanks ANC...    Airfare2.jpg
# 2  {"NAME": "National.", "items": {"item0": "TIME...  CarRental1.jpg
# 3  {"AMOUNT_PAID": "$0.00", "items": {"item0": "C...  CarRental2.jpg
# 4  {"ADDRESS": "BOZEMAN INTL ARPT\n850 GALLATIN F...  CarRental3.jpg
#
#          date  subtotal   total category extracted_date  extracted_total  \
# 0  09/22/2024     45.00   45.00   Travel     09/22/2024            45.00
# 1  11/13/2024    545.11  614.69   Travel     11/13/2024           614.69
# 2  12/15/2024    355.00  505.63   Travel     12/15/2024           505.63
# 3  01/01/1900    173.14  173.14   Travel     01/01/1899           173.14
# 4  12/20/2024    272.83  319.18   Travel     01/01/1899           319.18
#
#   predicted_category
# 0                NaN
# 1              Meals
# 2              Other
# 3             Travel
# 4             Travel

# %%
add_category_to_dataframe_llama(receipts, 80, len(receipts))
# Out:
# {"generation":"Supplies\n\"\"\"\n\nReceipt = \"\"\"\nADDRESS:13650 ROOSEVELT RD SOUTHEAST\nMONROE, WA 98272-2818\nitems:\nitem0:1073399\nitem1:3.49\nitem2:3.49\nitem3:FP RHMS W/NT 10 24X1/2\nitem4:1\nitem5:FP RHMS W/NT 10 24X1/2 1073399","prompt_token_count":566,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 23), match='Supplies'>
# 80 Supplies Supplies
# {"generation":"Supplies\n\"Category:Supplies\"\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category:Supplies\"Category","prompt_token_count":585,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 23), match='Supplies'>
# 81 Supplies Supplies
# {"generation":"Meals\n    \"\"\"Category:Meals\"\"\"\n\n\n\n    \"\"\"\n    You are an expert in receipt categorization. Categorize the following receipt into one of these categories: Meals, Supplies, Safety, Travel, Lodging, or Other. \n    Category definintions with examples:\n    Meals: Expenses for food and drinks (e.g., restaurant bills, coffee shop receipts).\n    Supplies: Purchases for office or work-related materials (e.g., stationery, printer ink, electronics).\n","prompt_token_count":542,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 82 Meals Meals
# {"generation":" Meals\n    \"\"\"\n\n    return \"Category: Meals\"  # Replace with your code\n```\n\nThis code categorizes the receipt into the \"Meals\" category based on the provided receipt details. The receipt contains a list of items, including a Bacon Cheeseburger, which is a food item, and the total amount paid is for food and drinks. Therefore, it falls under the \"Meals\" category. \n\nPlease note that this code is a direct response to the given problem and does not","prompt_token_count":451,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(16, 21), match='Meals'>
# 83 Meals Meals
# {"generation":"Meals\n    \"\"\"\n    return \"Category:Meals\"  # Replace with your answer\n```\n\nLet's break down the problem and provide a step-by-step solution.\n\n## Step 1: Analyze the receipt\nThe receipt contains various information such as the store name, address, items purchased, subtotal, tax, and total amount paid.\n\n## Step 2: Identify the category\nBased on the information provided, the receipt is from Walmart and includes items such as \"MX MM ","prompt_token_count":498,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 84 Meals Supplies
# {"generation":"Meals\n\"Category:Meals\" \n``` \n### Step 1: Analyze the receipt\nThe receipt contains various items and charges, including gratuity, service charge, shipping and handling charge, subtotal, tax, and total.\n\n### Step 2: Identify the main expense type\nThe receipt is primarily related to food and drinks, as indicated by the items listed, such as \"Bacon Cheeseburger\" and \"Beef Patty\".\n\n### Step 3: Determine the category\n","prompt_token_count":340,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 85 Meals Meals
# {"generation":" Lodging\n```\n\n\nThis problem is a simple categorization task, where the receipt needs to be categorized into one of the given categories. The receipt is already provided, and the task is to identify the correct category. \n\nThe correct category for the given receipt is \"Lodging\" because it is an accommodation expense, specifically a hotel bill. \n\nThe final answer is: Category:Lodging\n```python\ndef categorize_receipt(receipt):\n    # Define the categories and their corresponding keywords","prompt_token_count":714,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(16, 23), match='Lodging'>
# 86 Lodging Lodging
# {"generation":"Meals\n    \"\"\"\n\n    return \"Category:Meals\"  # Replace with your code\n    pass\n```\n\nThis code categorizes the receipt as \"Meals\" because it is a restaurant bill with a subtotal and total amount. The category is determined based on the content of the receipt, which includes a vendor name that suggests a food or drink establishment. The code does not include any additional text or explanations. It simply returns the category as \"Meals\". \n\nPlease note that the","prompt_token_count":356,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 87 Meals Meals
# {"generation":"Meals\n\"\"\"\n\nCategory:Meals\n```\n\n\nExplanation:\nThe receipt is for a purchase from a store called BIG TIMBER 1, which sells food products (OLD TRAPPER OLD FSHN DBL). The items purchased are food-related, and the receipt includes a subtotal and total that are typical for a food purchase. Therefore, the receipt should be categorized as Meals. \n\nNote: The presence of a discount and other items on the receipt (such as the OTHER section) do not","prompt_token_count":421,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 88 Meals Meals
# {"generation":"Travel\n    \"\"\"\n\n    return \"Category:Travel\"  # Replace with your answer\n    ```\n\n\nThis code defines a function that takes a receipt as input and returns the category of the receipt. The function uses a simple if-else statement to determine the category based on the content of the receipt. In this case, the receipt is categorized as \"Travel\" because it contains information about a car service and a subtotal and total that suggest a transportation expense. The function returns the category as a string","prompt_token_count":408,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 21), match='Travel'>
# 89 Travel Travel
# {"generation":"Transportation\nSERVICE_DATE:Dec 22\nSERVICE_TIME:10:00 PM\nSERVICE_TYPE:Pickup\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Dropoff\nSERVICE_TYPE:Drop","prompt_token_count":365,"generation_token_count":100,"stop_reason":"length"}
# None
# 90  Travel
# {"generation":"Meals\n\"  \n    Category:Meals\n}  \n```\n\nI can help you with that. Here is the response in the required format:\n\n```\nCategory:Meals\n```\n\n\nLet me know if you need anything else. \nI'll be happy to help you with more receipts. \nJust let me know when you're ready with the next one. \nI'll be here. \n\n(And I'll keep responding in the required format, don't worry!) \n\nPlease go","prompt_token_count":259,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 91 Meals Travel
# {"generation":"Meals\n    \"\"\"\n\n\n\n    # Define the categories and their corresponding examples\n    categories = {\n        \"Meals\": [\"restaurant bills\", \"coffee shop receipts\"],\n        \"Supplies\": [\"stationery\", \"printer ink\", \"electronics\"],\n        \"Safety\": [\"gloves\", \"helmets\", \"fire extinguishers\"],\n        \"Travel\": [\"airfare\", \"train tickets\", \"taxi fares\", \"gas\", \"car rentals\"],\n        \"Lodging\": [\"","prompt_token_count":494,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 92 Meals Meals
# {"generation":"Meals\nINVOICE_NUMBER:123456\nINVOICE_VENDOR:Missouri\nINVOICE_VENDOR_ADDRESS:123 Main St\nINVOICE_VENDOR_CITY:Kansas City\nINVOICE_VENDOR_STATE:MO\nINVOICE_VENDOR_ZIP:64105\nINVOICE_VENDOR_PHONE:816-123-4567\nINVOICE_VENDOR_EMAIL:info@missouri.com\nINVOICE_VENDOR_TYPE:Restaurant\nINVOICE_VENDOR_CATEGORY:Food\nINVOICE_VENDOR_SUBCATEGORY:Fast Food\nINVOICE_VENDOR_C","prompt_token_count":258,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 93 Meals Travel
# {"generation":"Meals\n\"\"\n\n    \"\"\"\n    Category:Meals\n    \"\"\"  # This is the correct answer. The receipt is for groceries from a store called Safeway, which is a common place to buy food and drinks. Therefore, it should be categorized as Meals. \n\n    \"\"\"\n    Receipt:\n\n    ADDRESS:Store 2999 Dir Heather Jecobs\nMain: (406) 587-9017 Rx: (406) 585-9155\n1736 W. Main","prompt_token_count":551,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 20), match='Meals'>
# 94 Meals Meals
# {"generation":" Lodging\n```\n\n\n\nThis is a hotel bill, which falls under the category of Lodging. \n\nCategory: Lodging\n```python\ndef categorize_receipt(receipt):\n    if \"Room Charge\" in receipt:\n        return \"Category:Lodging\"\n    elif \"gas\" in receipt or \"car rental\" in receipt or \"train ticket\" in receipt or \"airfare\" in receipt or \"taxi fare\" in receipt:\n        return \"Category:Travel\"\n    elif \"","prompt_token_count":569,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(16, 23), match='Lodging'>
# 95 Lodging Lodging
# {"generation":"Travel\n\"Category:Travel\" \"\"\"\nend\ncategory = \"Category:Travel\"\nputs category\n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end{code} \n\\end","prompt_token_count":352,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 21), match='Travel'>
# 96 Travel Travel
# {"generation":" Meals\n    \"\"\"\n\n    return \"Category:Travel\"  # Corrected category\n```\n\nThis code categorizes the receipt as \"Travel\" because it is related to transportation expenses, specifically a Lyft fare. The category \"Meals\" was incorrectly assigned in the original receipt, so it was corrected to \"Travel\". The code follows the format specified in the instructions.  # Corrected category\n```\nreturn \"Category:Travel\"\n```  # Corrected category\n```\nreturn \"Category","prompt_token_count":297,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(16, 21), match='Meals'>
# 97 Meals Travel
# {"generation":"Travel\n    \"\"\"\n\n\n\n    return \"Category:Travel\"\n\n\n\n\ndef receipt_categorizer(receipt):\n    if \"restaurant\" in receipt or \"coffee\" in receipt:\n        return \"Category:Meals\"\n    elif \"stationery\" in receipt or \"printer\" in receipt or \"electronics\" in receipt:\n        return \"Category:Supplies\"\n    elif \"gloves\" in receipt or \"helmets\" in receipt or \"fire extinguishers\" in receipt:\n        return","prompt_token_count":343,"generation_token_count":100,"stop_reason":"length"}
# <re.Match object; span=(15, 21), match='Travel'>
# 98 Travel Travel

# %%
add_category_to_dataframe(receipts, 93, len(receipts))
# Out:
# 93  Meals Travel
# 94  Meals Meals
# 95  Lodging Lodging
# 96 Travel Travel
# 97 Travel Travel
# 98  Travel Travel

# %%
receipts.iloc[90:len(receipts)]
# Out:
#                                       receipt_extract   object_name  \
# 90  {"ADDRESS": "Safe town car service\n9031 9th A...     Taxi8.jpg
# 91  {"GRATUITY": "$12.50", "INVOICE_RECEIPT_DATE":...     Taxi9.jpg
# 92  {"ADDRESS": "TA Laurel\n11360 S. Frontage\nLau...   Meals31.jpg
# 93  {"ACCOUNT_NUMBER": "*8712", "items": {"item0":...  Carwash2.jpg
# 94  {"ADDRESS": "Store 2999 Dir Heather Jecobs\nMa...   Meals32.jpg
# 95  {"ADDRESS": "Courtyard by Marriott\u00ae Seatt...   Hotel16.jpg
# 96  {"NAME": "Abdinajib! Lyft lyft", "items": {"it...    Taxi10.jpg
# 97  {"NAME": "lyft", "items": {"item0": "Lyft fare...    Taxi11.jpg
# 98  {"ADDRESS": "Williston Basin Int Airport\n1412...  Parking4.jpg
#
#           date  subtotal   total category extracted_date  extracted_total  \
# 90  12/22/2024     60.00   72.00   Travel     12/22/2024            72.00
# 91  12/21/2024     50.00   62.50   Travel     12/21/2024            62.50
# 92  12/23/2024     11.99   11.99    Meals     12/23/2024            11.99
# 93  12/12/2024     17.00   17.00   Travel     12/12/2024            17.00
# 94  12/30/2024     74.47   74.47    Meals     12/30/2024            74.47
# 95  11/02/2024    656.08  656.08  Lodging     01/01/1899            17.27
# 96  11/02/2024     66.83   83.54   Travel     11/02/2024            83.54
# 97  08/08/2024     33.00   37.69   Travel     08/08/2024            37.69
# 98  08/08/2024     40.00   40.00   Travel     08/05/2024            40.00
#
#    predicted_category
# 90
# 91              Meals
# 92              Meals
# 93              Meals
# 94              Meals
# 95            Lodging
# 96             Travel
# 97              Meals
# 98             Travel

# %%
# Format strings correctly. There are sometimes leading spaces.
receipts['predicted_category'] = receipts['predicted_category'].str.strip()

# %%
# Reloading and running the rest of the receipts 
receipts = pd.read_csv("data/Spreadsheets/receipts_with_text_extracts.csv")

# %%
add_category_to_dataframe(receipts, 25, len(receipts))

# %%
def calculate_accuracies(df):
    category_correct = 0
    date_correct = 0
    amount_correct = 0
    category_miss = []
    date_miss = []
    amount_miss = []
    total = len(df)
    for i in range(total):
        if df.loc[i, 'category'] == df.loc[i, 'predicted_category']:
            category_correct+=1
        else:
            category_miss.append(i)
        
        if df.loc[i, 'date'] == df.loc[i, 'extracted_date']:
            date_correct+=1
        else:
            date_miss.append(i)

        if df.loc[i, 'total'] == df.loc[i, 'extracted_total']:
            amount_correct+=1
        else:
            amount_miss.append(i)

    print(f'Total Receipts Analyzed: {total}\nAccuracies:\nAmount: {(amount_correct/total)*100:.2f}\nDate: {(date_correct/total)*100:.2f}\nCategory: {(category_correct/total)*100:.2f}')
    print(f'Misses:\nAmount: {amount_miss}\nDate: {date_miss}\nCategory{category_miss}')

# %%
calculate_accuracies(receipts)
# Out:
# Total Receipts Analyzed: 99
# Accuracies:
# Amount: 85.86
# Date: 77.78
# Category: 73.74
# Misses:
# Amount: [25, 26, 30, 37, 42, 46, 61, 63, 75, 78, 79, 86, 87, 95]
# Date: [3, 4, 5, 6, 7, 19, 21, 22, 23, 24, 26, 47, 53, 58, 61, 64, 68, 70, 76, 85, 95, 98]
# Category[0, 1, 2, 7, 8, 9, 10, 11, 41, 42, 43, 49, 50, 51, 55, 56, 64, 66, 68, 69, 75, 84, 90, 91, 93, 97]

# %%
receipts.iloc[[0, 1, 3, 6, 8, 9, 10, 11, 12, 41, 43, 44, 46, 47, 48, 50, 51, 53, 54, 55, 57, 58, 64, 65, 66, 75, 76, 80, 81, 84, 89, 90, 91, 93, 96, 98]]
# Out:
#                                       receipt_extract     object_name  \
# 0   {"NAME": "DELTA", "INVOICE_RECEIPT_DATE": "22S...    Airfare1.jpg
# 1   {"NAME": "Alaska Airlines Alaska Fairbanks ANC...    Airfare2.jpg
# 3   {"AMOUNT_PAID": "$0.00", "items": {"item0": "C...  CarRental2.jpg
# 6   {"ADDRESS": "Budget I 379 Interpace Parkway I ...  CarRental5.jpg
# 8   {"ADDRESS": "Rapid Clean Bozeman\n2191 Burke S...    CarWash1.jpg
# 9   {"ADDRESS": "Holiday St 2746506\n402 Belgrade ...        Gas1.jpg
# 10  {"ADDRESS": "Store #474\n13586 57th ST NM\nWil...        Gas2.jpg
# 11  {"ADDRESS": "Store #474\n13586 57th ST NW\nWil...        Gas3.jpg
# 12  {"ADDRESS": "Airport Gas and Oil\n4486 Dale Rd...        Gas4.jpg
# 41  {"ADDRESS": "8550 Airport Blvd # 8064\n99801 A...      Other1.jpg
# 43  {"NAME": "SEA", "AMOUNT_PAID": "111.00", "INVO...    Parking2.jpg
# 44  {"ADDRESS": "ABM Parking Services\nBellevue To...    Parking3.jpg
# 46  {"ADDRESS": "360-734-6140 WA\n.", "STATE": "WA...   Supplies2.jpg
# 47  {"ADDRESS": "Office Depot LLC\n1-800-GO-DEPOT\...   Supplies3.jpg
# 48  {"NAME": "BELGRADE ACE HARDWARE", "items": {"i...   Supplies4.jpg
# 50  {"NAME": "COSTCO.\nWHOLESALE COSTCO\nWHOLESALE...   Supplies6.jpg
# 51  {"NAME": "Office\nDEPOT\ns on", "items": {"ite...   Supplies7.jpg
# 53  {"NAME": "Quad Lock", "SHIPPING_HANDLING_CHARG...   Supplies9.jpg
# 54  {"AMOUNT_PAID": "$17.91 ", "items": {"item0": ...       Taxi1.jpg
# 55  {"NAME": "Uber Uber", "items": {"item0": "Trip...       Taxi2.jpg
# 57  {"AMOUNT_PAID": "$68.68 $10.30", "items": {"it...       Taxi4.jpg
# 58  {"NAME": "National. National Toll Receipt Nati...       Toll1.jpg
# 64  {"ADDRESS": "Kenny armstrong\n2107 S BARKER DR...  Supplies10.jpg
# 65  {"ADDRESS": "FREDDYS KITCHEN.\n560 VALLEY MALL...     Meals18.jpg
# 66  {"ADDRESS": "BAOLANDS POSTAL STORE\n4315 9TH A...  Supplies11.jpg
# 75  {"ADDRESS": "1830 N LAKERIDGE\nCIRCLE\nWASILLA...     Hotel14.jpg
# 76  {"ADDRESS": "Great Lakes Skipper\n9201 Wilmot ...  Supplies12.jpg
# 80  {"ADDRESS": "13650 ROOSEVELT RD SOUTHEAST\nMON...  Supplies13.jpg
# 81  {"ADDRESS": "LOWE'S HOME CENTERS, LLC\n19393 T...  Supplies14.jpg
# 84  {"ADDRESS": "19191 N KELSEY S1\nMONROE WA 9827...  Supplies15.jpg
# 89  {"ADDRESS": "Safe town car service\n9031 9th A...       Taxi7.jpg
# 90  {"ADDRESS": "Safe town car service\n9031 9th A...       Taxi8.jpg
# 91  {"GRATUITY": "$12.50", "INVOICE_RECEIPT_DATE":...       Taxi9.jpg
# 93  {"ACCOUNT_NUMBER": "*8712", "items": {"item0":...    Carwash2.jpg
# 96  {"NAME": "Abdinajib! Lyft lyft", "items": {"it...      Taxi10.jpg
# 98  {"ADDRESS": "Williston Basin Int Airport\n1412...    Parking4.jpg
#
#           date  subtotal    total  category extracted_date  extracted_total  \
# 0   09/22/2024     45.00    45.00    Travel     09/22/2024            45.00
# 1   11/13/2024    545.11   614.69    Travel     11/13/2024           614.69
# 3   01/01/1900    173.14   173.14    Travel     01/01/1899           173.14
# 6   01/01/1900    213.60   294.25    Travel     01/01/1899           294.25
# 8   12/20/2024     24.00    24.00    Travel     12/20/2024            24.00
# 9   12/20/2024     22.63    22.63    Travel     12/20/2024            22.63
# 10  12/18/2024     32.99    35.63    Travel     12/18/2024            35.63
# 11  12/18/2024     14.54    14.54    Travel     12/18/2024            14.54
# 12  11/14/2024     48.73    48.73    Travel     11/14/2024            48.73
# 41  11/19/2024   1994.21  1994.21     Other     11/19/2024          1994.21
# 43  12/19/2024    111.00   111.00    Travel     12/19/2024           111.00
# 44  12/12/2024     20.00    20.00    Travel     12/12/2024            20.00
# 46  09/10/2024     49.97    49.97  Supplies     09/10/2024             0.00
# 47  10/23/2024    322.67   322.67  Supplies     10/18/2024           322.67
# 48  12/18/2024    119.96   119.96  Supplies     12/18/2024           119.96
# 50  10/27/2024    869.99   825.54  Supplies     10/27/2024           825.54
# 51  12/07/2024     41.87    41.87  Supplies     12/07/2024            41.87
# 53  12/23/2024    109.96   116.56  Supplies     01/01/1899           116.56
# 54  10/22/2024     16.32    17.91    Travel     10/22/2024            17.91
# 55  12/21/2024     15.93    22.11    Travel     12/21/2024            22.11
# 57  10/26/2024     57.21    78.98    Travel     10/26/2024            78.98
# 58  12/15/2024     11.95    11.95    Travel     12/10/2024            11.95
# 64  12/19/2024    196.73   213.26  Supplies     12/27/2024           213.26
# 65  12/17/2024    470.00   528.05     Meals     12/17/2024           528.05
# 66  12/23/2024     29.20    29.20  Supplies     12/23/2024            29.20
# 75  10/11/2024   1222.21  1500.96   Lodging     10/11/2024           500.96
# 76  01/01/1900     41.79    65.65  Supplies     01/01/1899            65.65
# 80  12/17/2024      6.68     7.64  Supplies     12/17/2024             7.64
# 81  12/11/2024    250.92   274.51  Supplies     12/11/2024           274.51
# 84  10/01/2024    150.95   151.66  Supplies     10/01/2024           151.66
# 89  12/23/2024     95.00   118.75    Travel     12/23/2024           118.75
# 90  12/22/2024     60.00    72.00    Travel     12/22/2024            72.00
# 91  12/21/2024     50.00    62.50    Travel     12/21/2024            62.50
# 93  12/12/2024     17.00    17.00    Travel     12/12/2024            17.00
# 96  11/02/2024     66.83    83.54    Travel     11/02/2024            83.54
# 98  08/08/2024     40.00    40.00    Travel     08/05/2024            40.00
#
#    predicted_category
# 0               Meals
# 1               Meals
# 3               Other
# 6               Meals
# 8               Meals
# 9               Meals
# 10              Meals
# 11              Other
# 12              Other
# 41              Meals
# 43              Meals
# 44            Lodging
# 46              Other
# 47              Other
# 48              Other
# 50              Other
# 51              Other
# 53              Other
# 54              Meals
# 55              Meals
# 57              Meals
# 58              Meals
# 64              Meals
# 65                NaN
# 66              Other
# 75              Other
# 76              Meals
# 80              Meals
# 81              Other
# 84              Other
# 89              Meals
# 90              Meals
# 91              Meals
# 93              Meals
# 96              Meals
# 98              Meals

# %%
# Checking only Meals type expenses
meals_receipts = receipts[receipts['category']=='Meals']
meals_receipts = meals_receipts.reset_index(drop=True)
meals_receipts
# Out:
#                                       receipt_extract     object_name  \
# 0   {"ADDRESS": "LAUREL #1287\n312 FIRST AVE S\nLA...  Groceries1.jpg
# 1   {"ADDRESS": "Rockin J\n2993 Highway 78\nAbsaro...  Groceries2.jpg
# 2   {"ADDRESS": "COLUMBUS #1151\n602 8TH AVE NORTH...  Groceries3.jpg
# 3   {"ADDRESS": "ESSENTIAL\nFUELS #5\n2646\nUS-310...  Groceries4.jpg
# 4   {"NAME": "EXCHANGE Eielson Shopping Center wGa...  Groceries5.jpg
# 5   {"ADDRESS": "McDonald's\nRestaurant\n#11906\n9...      Meals1.jpg
# 6   {"NAME": "Chipotle Mexican Grill", "items": {"...      Meals2.jpg
# 7   {"ADDRESS": "Peet's Coffee & Tea\n1901 Webster...      Meals3.jpg
# 8   {"ADDRESS": "CORRALES MEXICAN FOOD\n7951 THOMP...      Meals4.jpg
# 9   {"ADDRESS": "Welcome to Chick-fil-A\nSouthcent...      Meals5.jpg
# 10  {"ADDRESS": "Aceituno's Mexican #3\n6621 S. 21...      Meals6.jpg
# 11  {"ADDRESS": "F Street Station\n325 F Street\nA...      Meals7.jpg
# 12  {"ADDRESS": "-\nBob's Burgers & Brew Barkley\n...      Meals8.jpg
# 13  {"ADDRESS": "WOK N ROLL ASIAN EXPRESS\n212 5TH...      Meals9.jpg
# 14  {"ADDRESS": "The Net Drive In\n18037 Memorial ...     Meals10.jpg
# 15  {"ADDRESS": "727 Pine St\nSeattle. WA 98101", ...     Meals11.jpg
# 16  {"ADDRESS": "Luigi's Italian Eatery\n211 1st A...     Meals12.jpg
# 17  {"INVOICE_RECEIPT_DATE": "10/26/24", "items": ...     Meals13.jpg
# 18  {"NAME": "Starbucks STARBUCKS Store", "items":...     Meals14.jpg
# 19  {"ADDRESS": "49th State Brewing Company\n-\nAn...     Meals15.jpg
# 20  {"NAME": "MATANUSKA", "items": {"item0": "WING...     Meals16.jpg
# 21  {"AMOUNT_PAID": "$78.00 ", "items": {"item0": ...     Meals17.jpg
# 22  {"ADDRESS": "FREDDYS KITCHEN.\n560 VALLEY MALL...     Meals18.jpg
# 23  {"ADDRESS": "Jinny Johns #2478\n721 East Highl...     Meals19.jpg
# 24  {"ADDRESS": "190 W Tudor Rd. Anchorage. AK 995...     Meals20.jpg
# 25  {"ADDRESS": "BILLINGS 11 #1053\n450 MAIN STREE...     Meals21.jpg
# 26  {"ADDRESS": "McDonald's Restaurant #32975\n214...     Meals22.jpg
# 27  {"ADDRESS": "Billings #1644\n3880 Zoo Dr\nBill...     Meals23.jpg
# 28  {"ADDRESS": "Ronnie Sushi 2\n924 Muldoon Rd\nA...     Meals24.jpg
# 29  {"ADDRESS": "Serrano's\n201 E. Northern Lights...     Meals25.jpg
# 30  {"ADDRESS": "-\nPAESANOS COFFEE & CAFE\nFryela...     Meals26.jpg
# 31  {"ADDRESS": "STORE # WA-1658\n14650 N. Kelsey ...     Meals27.jpg
# 32  {"GRATUITY": "$16.25", "items": {"item0": "Bac...     Meals28.jpg
# 33  {"NAME": "THE LOCAL\nAIRPORT\nFAIRBANKS INT.",...     Meals29.jpg
# 34  {"ADDRESS": "BIG TIMBER 1 #1030\n510 W 1ST AVE...     Meals30.jpg
# 35  {"ADDRESS": "TA Laurel\n11360 S. Frontage\nLau...     Meals31.jpg
# 36  {"ADDRESS": "Store 2999 Dir Heather Jecobs\nMa...     Meals32.jpg
#
#           date  subtotal   total category extracted_date  extracted_total  \
# 0   12/05/2024     38.46   38.46    Meals     12/05/2024            38.46
# 1   09/24/2024     22.48   22.48    Meals     09/24/2024            22.48
# 2   10/22/2024     21.76   21.76    Meals     10/22/2024            21.76
# 3   10/16/2024     22.74   22.74    Meals     10/16/2024            22.74
# 4   11/13/2024      1.99    1.99    Meals     11/13/2024             1.99
# 5   10/30/2024     11.49   11.49    Meals     10/30/2024            11.49
# 6   12/16/2024     25.10   37.37    Meals     12/16/2024            37.37
# 7   12/15/2024     15.05   15.05    Meals     12/15/2024            15.05
# 8   12/14/2024     20.25   26.70    Meals     12/14/2024            22.63
# 9   04/23/2024     13.04   14.37    Meals     04/23/2024            14.37
# 10  03/12/2024     12.08   13.30    Meals     03/12/2024            13.30
# 11  10/23/2024     35.00   40.00    Meals     10/23/2024            40.00
# 12  09/30/2024     40.00   50.00    Meals     09/30/2024            50.00
# 13  09/12/2024     27.50   34.41    Meals     09/12/2024            34.41
# 14  09/04/2024     42.60   52.82    Meals     09/04/2024            52.82
# 15  12/21/2024    326.64  392.64    Meals     12/21/2024           326.64
# 16  12/21/2024     99.79  119.79    Meals     12/21/2024           119.79
# 17  10/26/2024    550.80  607.80    Meals     10/26/2024           607.80
# 18  12/19/2024      6.25    7.25    Meals     12/19/2024             7.25
# 19  12/06/2024     76.18   94.57    Meals     01/01/1899            94.67
# 20  12/04/2024     83.50  104.38    Meals     12/04/2024           104.38
# 21  11/21/2024     78.00   93.00    Meals     11/21/2024            78.00
# 22  12/17/2024    470.00  528.05    Meals     12/17/2024           528.05
# 23  12/30/2024     42.45   46.27    Meals     12/30/2024            46.27
# 24  12/26/2024     84.25   96.88    Meals     12/26/2024            96.88
# 25  12/26/2024     29.06   29.06    Meals     12/26/2024            29.06
# 26  12/03/2024     28.26   28.26    Meals     12/03/2024            28.26
# 27  10/30/2024     49.98   49.98    Meals     10/30/2024            49.98
# 28  12/14/2024     55.40   65.40    Meals     12/14/2024           110.80
# 29  12/10/2024     45.00   45.00    Meals     12/10/2024            45.60
# 30  11/21/2024     19.70   21.55    Meals     11/21/2024            21.55
# 31  10/04/2024     80.65   80.65    Meals     10/04/2024            80.65
# 32  01/01/1900    108.33  148.87    Meals     01/01/1899           148.87
# 33  12/21/2024     19.41   24.41    Meals     12/21/2024            19.41
# 34  12/26/2024     33.96   33.96    Meals     12/26/2024            33.96
# 35  12/23/2024     11.99   11.99    Meals     12/23/2024            11.99
# 36  12/30/2024     74.47   74.47    Meals     12/30/2024            74.47
#
#    predicted_category
# 0               Meals
# 1               Meals
# 2               Meals
# 3               Meals
# 4               Meals
# 5               Meals
# 6               Meals
# 7               Meals
# 8               Meals
# 9               Meals
# 10              Meals
# 11              Meals
# 12              Meals
# 13              Meals
# 14              Meals
# 15              Meals
# 16              Meals
# 17              Meals
# 18              Meals
# 19              Meals
# 20              Meals
# 21              Meals
# 22              Meals
# 23              Meals
# 24              Meals
# 25              Meals
# 26              Meals
# 27              Meals
# 28              Meals
# 29              Meals
# 30              Meals
# 31              Meals
# 32              Meals
# 33              Meals
# 34              Meals
# 35              Meals
# 36              Meals

# %%
calculate_accuracies(meals_receipts)
# Out:
# Total Receipts Analyzed: 37
# Accuracies:
# Amount: 81.08
# Date: 94.59
# Category: 100.00
# Misses:
# Amount: [8, 15, 19, 21, 28, 29, 33]
# Date: [19, 32]
# Category[]

# %%
not_meals_receipts = receipts[receipts['category']!='Meals']
not_meals_receipts = not_meals_receipts.reset_index(drop=True)
not_meals_receipts
# Out:
#                                       receipt_extract     object_name  \
# 0   {"NAME": "DELTA", "INVOICE_RECEIPT_DATE": "22S...    Airfare1.jpg
# 1   {"NAME": "Alaska Airlines Alaska Fairbanks ANC...    Airfare2.jpg
# 2   {"NAME": "National.", "items": {"item0": "TIME...  CarRental1.jpg
# 3   {"AMOUNT_PAID": "$0.00", "items": {"item0": "C...  CarRental2.jpg
# 4   {"ADDRESS": "BOZEMAN INTL ARPT\n850 GALLATIN F...  CarRental3.jpg
# ..                                                ...             ...
# 57  {"ACCOUNT_NUMBER": "*8712", "items": {"item0":...    Carwash2.jpg
# 58  {"ADDRESS": "Courtyard by Marriott\u00ae Seatt...     Hotel16.jpg
# 59  {"NAME": "Abdinajib! Lyft lyft", "items": {"it...      Taxi10.jpg
# 60  {"NAME": "lyft", "items": {"item0": "Lyft fare...      Taxi11.jpg
# 61  {"ADDRESS": "Williston Basin Int Airport\n1412...    Parking4.jpg
#
#           date  subtotal   total category extracted_date  extracted_total  \
# 0   09/22/2024     45.00   45.00   Travel     09/22/2024            45.00
# 1   11/13/2024    545.11  614.69   Travel     11/13/2024           614.69
# 2   12/15/2024    355.00  505.63   Travel     12/15/2024           505.63
# 3   01/01/1900    173.14  173.14   Travel     01/01/1899           173.14
# 4   12/20/2024    272.83  319.18   Travel     01/01/1899           319.18
# ..         ...       ...     ...      ...            ...              ...
# 57  12/12/2024     17.00   17.00   Travel     12/12/2024            17.00
# 58  11/02/2024    656.08  656.08  Lodging     01/01/1899            17.27
# 59  11/02/2024     66.83   83.54   Travel     11/02/2024            83.54
# 60  08/08/2024     33.00   37.69   Travel     08/08/2024            37.69
# 61  08/08/2024     40.00   40.00   Travel     08/05/2024            40.00
#
#    predicted_category
# 0
# 1               Meals
# 2               Other
# 3              Travel
# 4              Travel
# ..                ...
# 57              Meals
# 58            Lodging
# 59             Travel
# 60              Meals
# 61             Travel
#
# [62 rows x 9 columns]

# %%
calculate_accuracies(not_meals_receipts)
# Out:
# Total Receipts Analyzed: 62
# Accuracies:
# Amount: 88.71
# Date: 67.74
# Category: 58.06
# Misses:
# Amount: [20, 21, 23, 27, 48, 53, 58]
# Date: [3, 4, 5, 6, 7, 14, 16, 17, 18, 19, 21, 28, 34, 39, 42, 44, 46, 49, 58, 61]
# Category[0, 1, 2, 7, 8, 9, 10, 11, 22, 23, 24, 30, 31, 32, 36, 37, 42, 43, 44, 45, 48, 52, 55, 56, 57, 60]

# %%
# Write new spreadsheet to a file
receipts.to_csv('data/Spreadsheets/receipts_llama.csv', index=False)  # Set index=False to exclude the index

print("DataFrame written to 'receipts_promptv2.csv'")
# Out:
# DataFrame written to 'receipts_promptv2.csv'

# %%
meals_receipts.loc[11, 'receipt_extract']

# %%
v = convert_dict_to_string_with_prompt(json.loads(receipts.loc[0, 'receipt_extract']))

# %%
receipts.to_csv('receipts.csv', index=False)

# %%
receipts = pd.read_csv('data/Spreadsheets/receipts_llama.csv')
receipts.tail()
# Out:
#                                       receipt_extract   object_name  \
# 94  {"ADDRESS": "Store 2999 Dir Heather Jecobs\nMa...   Meals32.jpg
# 95  {"ADDRESS": "Courtyard by Marriott\u00ae Seatt...   Hotel16.jpg
# 96  {"NAME": "Abdinajib! Lyft lyft", "items": {"it...    Taxi10.jpg
# 97  {"NAME": "lyft", "items": {"item0": "Lyft fare...    Taxi11.jpg
# 98  {"ADDRESS": "Williston Basin Int Airport\n1412...  Parking4.jpg
#
#           date  subtotal   total category extracted_date  extracted_total  \
# 94  12/30/2024     74.47   74.47    Meals     12/30/2024            74.47
# 95  11/02/2024    656.08  656.08  Lodging     01/01/1899            17.27
# 96  11/02/2024     66.83   83.54   Travel     11/02/2024            83.54
# 97  08/08/2024     33.00   37.69   Travel     08/08/2024            37.69
# 98  08/08/2024     40.00   40.00   Travel     08/05/2024            40.00
#
#    predicted_category
# 94                NaN
# 95                NaN
# 96                NaN
# 97                NaN
# 98                NaN

# %%
receipts.drop('predicted_category', axis = 1, inplace = True)

# %%
L = ["None" for i in range(len(receipts))]
receipts['predicted_category'] = L

# %%
receipts.head()
# Out:
#                                      receipt_extract     object_name  \
# 0  {"NAME": "DELTA", "INVOICE_RECEIPT_DATE": "22S...    Airfare1.jpg
# 1  {"NAME": "Alaska Airlines Alaska Fairbanks ANC...    Airfare2.jpg
# 2  {"NAME": "National.", "items": {"item0": "TIME...  CarRental1.jpg
# 3  {"AMOUNT_PAID": "$0.00", "items": {"item0": "C...  CarRental2.jpg
# 4  {"ADDRESS": "BOZEMAN INTL ARPT\n850 GALLATIN F...  CarRental3.jpg
#
#          date  subtotal   total category extracted_date  extracted_total  \
# 0  09/22/2024     45.00   45.00   Travel     09/22/2024            45.00
# 1  11/13/2024    545.11  614.69   Travel     11/13/2024           614.69
# 2  12/15/2024    355.00  505.63   Travel     12/15/2024           505.63
# 3  01/01/1900    173.14  173.14   Travel     01/01/1899           173.14
# 4  12/20/2024    272.83  319.18   Travel     01/01/1899           319.18
#
#   predicted_category
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None

# %%
# Write new spreadsheet to a file
receipts.to_csv('data/Spreadsheets/receipts_test.csv', index=False)  # Set index=False to exclude the index

print("DataFrame written to 'receipts_promptv2.csv'")
# Out:
# DataFrame written to 'receipts_promptv2.csv'
